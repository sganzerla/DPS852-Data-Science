# %% [markdown]
# Construindo o dataframe com o indicador 'GDP per capita', excluindo as colunas 'Indicator Name' e 'Indicator Code' e persistindo o resultado no arquivo 'gfdd_gdp.csv':

# %%
from google.colab import drive 
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta

drive.mount('/content/gdrive')

caminho='gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_21_24/'
#caminho='./'

nome='dataset_bancomundial.csv'

nomecaminho=caminho+nome

# le o dataset cujo nome esta definido na variavel 'nomecaminho'
gfdd = pd.read_csv(nomecaminho, sep=';', decimal=',')

conteudo_coluna='GDP per capita'

gfdd_linhas_gdp = gfdd[ gfdd['Indicator Name'].str.contains(conteudo_coluna) ]
gfdd_linhas_gdp = gfdd_linhas_gdp.reset_index(drop=True)

#print(gfdd_linhas_gdp)

colunas_para_excluir=[ 'Indicator Name', 'Indicator Code' ]

gfdd_gdp=gfdd_linhas_gdp.drop(colunas_para_excluir, axis=1)

nome_saida='gfdd_gdp.csv'
nomecaminho_saida=caminho+nome_saida
gfdd_gdp.to_csv(nomecaminho_saida, index=False, sep=';')

gfdd_gdp
# Out:
# Mounted at /content/gdrive
#      index        Country Name Country Code  \
# 0       56         Afghanistan          AFG
# 1      171             Albania          ALB
# 2      286             Algeria          DZA
# 3      401             Andorra          ADO
# 4      516              Angola          AGO
# ..     ...                 ...          ...
# 212  24436  West Bank and Gaza          WBG
# 213  24551               World          WLD
# 214  24666         Yemen, Rep.          YEM
# 215  24781              Zambia          ZMB
# 216  24896            Zimbabwe          ZWE
#
#                          Indicator Name  Indicator Code         1960  \
# 0    GDP per capita (Constant 2005 USD)  NY.GDP.PCAP.KD          NaN
# 1    GDP per capita (Constant 2005 USD)  NY.GDP.PCAP.KD          NaN
# 2    GDP per capita (Constant 2005 USD)  NY.GDP.PCAP.KD  1765.594712
# 3    GDP per capita (Constant 2005 USD)  NY.GDP.PCAP.KD          NaN
# ...

# %% [markdown]
# Buscando os países da América do Sul do dataset 'dataset_bancomundial_paises.csv' e criando o dataset 'gfdd_paises_america_sul':

# %%
from google.colab import drive 
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta

drive.mount('/content/gdrive')

caminho='gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_21_24/'
#caminho='./'

nome='dataset_bancomundial_paises.csv'

nomecaminho=caminho+nome

# le o dataset cujo nome esta definido na variavel 'nomecaminho'
gfdd_paises = pd.read_csv(nomecaminho, sep=';', decimal=',')

gfdd_paises.columns

print(gfdd_paises['Region'].unique())

regiao_intesse='Latin America'

gfdd_paises.fillna( '0', inplace=True )
gfdd_paises_america_latina_caribe = gfdd_paises[ gfdd_paises['Region'].str.contains(regiao_intesse) ]

gfdd_paises_america_latina_caribe = gfdd_paises_america_latina_caribe[['Country Code','Short Name']]

print(gfdd_paises_america_latina_caribe)

codigos=gfdd_paises_america_latina_caribe['Country Code'].to_numpy()

codigos_paises_america_sul = [ 'ARG', 'BOL', 'BRA', 'CHL', 'COL', 'ECU', 'GUY', 'PRY', 'PER', 'SUR', 'URY', 'VEN' ]

vazio=1
for pais in codigos_paises_america_sul:
    sel=gfdd_paises_america_latina_caribe[ gfdd_paises_america_latina_caribe['Country Code'].str.contains(pais) ]
    if( vazio==1 ):
        gfdd_paises_america_sul=sel
        vazio=0
    else:
        gfdd_paises_america_sul= pd.concat([gfdd_paises_america_sul,sel],ignore_index=True)

print(gfdd_paises_america_sul)
    
nome_saida='gfdd_paises_america_sul.csv'
nomecaminho_saida=caminho+nome_saida
gfdd_paises_america_sul.to_csv(nomecaminho_saida, index=False, sep=';')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['South Asia' 'Europe & Central Asia' 'Middle East & North Africa'
#  'Sub-Saharan Africa' 'Latin America & Caribbean' 'East Asia & Pacific'
#  'North America' nan]
#     Country Code                      Short Name
# 5            ATG             Antigua and Barbuda
# 6            ARG                       Argentina
# 8            ABW                           Aruba
# 14           BRB                        Barbados
# 17           BLZ                          Belize
# 21           BOL                         Bolivia
# 24           BRA                          Brazil
# 33           CYM                  Cayman Islands
# 36           CHL                           Chile
# 38           COL                        Colombia
# 41           CRI                      Costa Rica
# 44           CUB                            Cuba
# ...

# %% [raw]
# Buscando os países da América do Sul do dataset 'gfdd_gdp.csv' e criando o dataset 'gfdd_gdp_paises_america_sul':

# %%
from google.colab import drive 
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta

drive.mount('/content/gdrive')

caminho='gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_21_24/'
#caminho='./'

nome='gfdd_gdp.csv'

nomecaminho=caminho+nome

# le o dataset cujo nome esta definido na variavel 'nomecaminho'
gfdd_gdp = pd.read_csv(nomecaminho, sep=';', decimal=',')

#print(gfdd_gdp)

nome='gfdd_paises_america_sul.csv'

nomecaminho=caminho+nome

gfdd_paises_america_sul = pd.read_csv(nomecaminho, sep=';', decimal=',')

#print(gfdd_paises_america_sul)

codigos_paises_america_sul=gfdd_paises_america_sul['Country Code'].to_numpy()


vazio=1
for pais in codigos_paises_america_sul:
    sel=gfdd_gdp[ gfdd_gdp['Country Code'].str.contains(pais) ]
    if( vazio==1 ):
        gfdd_gdp_paises_america_sul=sel
        vazio=0
    else:
        gfdd_gdp_paises_america_sul= pd.concat([gfdd_gdp_paises_america_sul,sel],ignore_index=True)

print(gfdd_gdp_paises_america_sul)

nome_saida='gfdd_gdp_paises_america_sul.csv'
nomecaminho_saida=caminho+nome_saida
gfdd_gdp_paises_america_sul.to_csv(nomecaminho_saida, index=False, sep=';')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#     index   Country Name Country Code         1960         1961         1962  \
# 0     746      Argentina          ARG  3732.330981  3871.977071  3778.406097
# 1    2586        Bolivia          BOL  874.2862486   872.908987  901.2483892
# 2    2931         Brazil          BRA  1726.566347  1847.818993  1886.379547
# 3    4311          Chile          CHL  2479.185118  2514.911146  2579.127548
# 4    4541       Colombia          COL  1452.070326  1483.790202  1519.085708
# 5    6381        Ecuador          ECU  1593.158191    1572.4319  1597.720999
# 6    9141         Guyana          GUY  769.5516028  783.7076897  771.3561226
# 7   17766       Paraguay          PRY  569.5127394  592.9515741  596.5027534
# 8   17881           Peru          PER  1855.983158  1936.505045  2038.392034
# ...
