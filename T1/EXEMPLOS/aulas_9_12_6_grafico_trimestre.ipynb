# %% [markdown]
# Exemplo de plot para um ano:

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

trimestres = ['1', '2', '3', '4']
leituras = [45,48,60,56]
ax.bar(trimestres,leituras)
plt.show()
