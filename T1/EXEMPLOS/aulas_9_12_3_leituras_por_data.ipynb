# %% [markdown]
# Contando o número de leituras em cada data:

# %%
# from google.colab import drive 
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta

# drive.mount('/content/gdrive')

# caminho='/content/gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_9_12_python/'
#caminho='gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_9_12_python/'
caminho='./'

dataset='dataset_reg_chuva_santa_maria_2011_2020_2.csv'

caminho_dataset=caminho+dataset

# le o dataset cujo nome esta definido na variavel 'dataset'
precipitacao = pd.read_csv(caminho_dataset, sep=';')

precipitacao=precipitacao.sort_values(by=['DT_MEDICAO', 'HR_MEDICAO'])

precipitacao=precipitacao.reset_index(drop=True)

# data inicial
datas=precipitacao['DT_MEDICAO']
data_inicial=datas[0]

# data final
data_inicial_date=datetime.strptime(data_inicial, '%Y-%m-%d')

num_linhas=len(precipitacao)
data_final=datas[num_linhas-1]
data_final_date=datetime.strptime(data_final, '%Y-%m-%d')

# vetor com as datas a partir da data_inicial
dif_data_final_data_inicial=data_final_date-data_inicial_date
datas_periodo = pd.date_range(data_inicial_date, periods=(dif_data_final_data_inicial.days+1))

# construindo um array com zeros do tamanho de 'datas_periodo'
leituras=np.zeros(len(datas_periodo),dtype=int)

base={ 'datas': datas_periodo, 'leituras': leituras }
dias_periodo_leituras=pd.DataFrame(base)

# contando o numero de leituras em cada data
for i,linha in dias_periodo_leituras.iterrows():
    #dias_periodo_leituras.at[i,'leituras']=int(1)
    datai=linha['datas']
    datais=datai.strftime('%Y-%m-%d')
    # procurando a 'datai' no dataframe 'precipitacao'
    linhas_sel=precipitacao.loc[ precipitacao['DT_MEDICAO']==datais ]
    # ajustando o numero de leituras
    dias_periodo_leituras.at[i,'leituras']=len(linhas_sel)
  
# verificando o 'dataframe' com o numero de leituras registrado
print(dias_periodo_leituras)

# escreve o resultado para o arquivo 'dias_periodo_leituras.csv'
nome_arquivo='dias_periodo_leituras.csv'
nome_caminho_arquivo_saida=caminho+nome_arquivo
dias_periodo_leituras.to_csv(nome_caminho_arquivo_saida, index=False, sep=';')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#           datas  leituras
# 0    2011-01-01        14
# 1    2011-01-02        14
# 2    2011-01-03        14
# 3    2011-01-04        16
# 4    2011-01-05        20
# ...         ...       ...
# 3648 2020-12-27        11
# 3649 2020-12-28        16
# 3650 2020-12-29        13
# 3651 2020-12-30        14
# 3652 2020-12-31        17
#
# [3653 rows x 2 columns]
