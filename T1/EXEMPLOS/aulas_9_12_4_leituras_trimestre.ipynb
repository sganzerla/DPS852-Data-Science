# %%
# from google.colab import drive 
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta
import math

# drive.mount('/content/gdrive')

# caminho='gdrive/MyDrive/ufsm/aulas/introducao_ciencia_analise_dados_2022_1/aulas_9_12_python/'
caminho='./'

datasetleituras='dias_periodo_leituras.csv'

caminho_dataset=caminho+datasetleituras

# le o dataset cujo nome esta definido na variavel 'dataset'
dias_periodo_leituras = pd.read_csv(caminho_dataset, sep=';', parse_dates=['datas'] )

num_datas=len(dias_periodo_leituras)

data_inicial=dias_periodo_leituras.at[0,'datas']
data_final=dias_periodo_leituras.at[num_datas-1,'datas']

print(data_inicial)
print(data_final)

dif_datas=(data_final.to_period('M')-data_inicial.to_period('M'))

meses=dif_datas.n

print('meses: ',meses)

trimestres=math.ceil(meses/3)

print('trimestres: ',trimestres)

#serie_trimestres=pd.date_range(start=data_inicial, periods=trimestres, freq='90d')
serie_trimestres=pd.date_range(start='2011-01', periods=39, freq='3M')

print(serie_trimestres)

anos=[]

anoi=2011
mesi=[1,4,7,10]
diai=1
mesf=[3,6,9,12]
diaf=[31, 30, 30, 31]

serie_trimestres2=[]

for i in range(10):
  for j in range(4):
      #print(anoi+i,'-',mesi[j], '-', diai,' ->  ', anoi+i, '-', mesf[j], '-', diaf[j])
      trimestrei=str(anoi+i)+'-'+str(mesi[j])+'-'+str(diai)+' ->  '+str(anoi+i)+'-'+str(mesf[j])+'-'+str(diaf[j])
      serie_trimestres2.append(trimestrei)
      #print(trimestrei)

print(serie_trimestres2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\aliss\source\repos\ufsm\DPS852-Jupyter-Notebooks\T1\aulas_9_12_4_leituras_trimestre.ipynb Cell 1' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aliss/source/repos/ufsm/DPS852-Jupyter-Notebooks/T1/aulas_9_12_4_leituras_trimestre.ipynb#ch0000001?line=13'>14</a> caminho_dataset=caminho+datasetleituras
#      <a href='vscode-notebook-cell:/c%3A/Users/aliss/source/repos/ufsm/DPS852-Jupyter-Notebooks/T1/aulas_9_12_4_leituras_trimestre.ipynb#ch0000001?line=15'>16</a> # le o dataset cujo nome esta definido na variavel 'dataset'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aliss/source/repos/ufsm/DPS852-Jupyter-Notebooks/T1/aulas_9_12_4_leituras_trimestre.ipynb#ch0000001?line=16'>17</a> dias_periodo_leituras = pd.read_csv(caminho_dataset, sep=';', parse_dates=['datas'] )
# ...
